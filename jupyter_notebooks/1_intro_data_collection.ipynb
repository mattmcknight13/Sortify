# %% [markdown]
# ### Problem Statement

# %% [markdown]
# I am going to build a music recommender system using the Spotify and Genius APIs. The app will sort an ablum entered in the order of songs the user will mostly likely like by analyzing the audio features and lyrics of the users recently saved tracks, recently played tracks, and top tracks.

# %% [markdown]
# ### Library/Packages Import

# %%
import pandas as pd
import numpy as np
from time import sleep
from re import sub

import spotipy
from spotipy.oauth2 import SpotifyOAuth

import lyricsgenius

pd.set_option('display.max_rows', None)

# %% [markdown]
# ### API User Authorization

# %%
cid = '01e5c3c39a334ae78bf5becf053ad2d5'
secret = '3c481468946e43dc9da43ed6b5c16bc8'
uri = 'http://localhost:9999/lab/workspaces/auto-c'
cache = '.spotipyoauthcache'
scope = 'user-read-recently-played user-library-read user-top-read'

# 'user-read-recently-played' --> Get Current User's Recently Played Tracks
# 'user-top-read' --> Get a User's Top Artists and Tracks
# 'user-library-read' --> Get a User's Saved Tracks

# %%
auth = SpotifyOAuth(client_id = cid,
                    client_secret = secret,
                    redirect_uri = uri,
                    cache_path = cache,
                    scope = scope)

sp = spotipy.Spotify(oauth_manager = auth)
sp.current_user()
# Out:
# {'display_name': 'Aziz Maredia',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/1282060363'},
#  'followers': {'href': None, 'total': 36},
#  'href': 'https://api.spotify.com/v1/users/1282060363',
#  'id': '1282060363',
#  'images': [{'height': None,
#    'url': 'https://scontent-ort2-2.xx.fbcdn.net/v/t1.0-1/p320x320/79640598_10158654118142079_1999166169432457216_n.jpg?_nc_cat=104&ccb=2&_nc_sid=0c64ff&_nc_ohc=YhL1x0dnItoAX-NJCyI&_nc_ht=scontent-ort2-2.xx&tp=6&oh=3e3aca2ea60f52a16b9d2af9bfcf9c17&oe=600C46A9',
#    'width': None}],
#  'type': 'user',
#  'uri': 'spotify:user:1282060363'}

# %% [markdown]
# ### User Top Tracks

# %%
def get_top_tracks(var = None):
 
    df = None
    
    for i in range(0, 60, 20):
        
        results = sp.current_user_top_tracks(offset = i)

        top_tracks_dict = {}

        top_tracks_dict['track'] = [i['name'] for i in results['items']]
        top_tracks_dict['artist'] = [i['artists'][0]['name'] for i in results['items']]
        top_tracks_dict['album'] = [i['album']['name'] for i in results['items']]
        top_tracks_dict['popularity_score'] = [i['popularity'] for i in results['items']]
        top_tracks_dict['track_id'] = [i['id'] for i in results['items']]
        top_tracks_dict['track_uri'] = [i['uri'] for i in results['items']]
        top_tracks_dict['spotify_link'] = [i['external_urls']['spotify'] for i in results['items']]
        top_tracks_dict['preview'] = [i['preview_url'] for i in results['items']]
        top_tracks_dict['album_image_large'] = [i['album']['images'][1]['url'] for i in results['items']]
        top_tracks_dict['album_image_small'] = [i['album']['images'][2]['url'] for i in results['items']]
    
        if i == 0:
            df = pd.DataFrame(top_tracks_dict)
        
        else:
            df = pd.concat([df, pd.DataFrame(top_tracks_dict)])
            df.reset_index(drop = True, inplace = True)
    
    return df

# %% [markdown]
# ### User Current Saved

# %%
def get_current_saved(var = None):
    
    df = None
    
    for i in range(0, 200, 20):
    
        results = sp.current_user_saved_tracks(offset = i)

        current_saved_dict = {}

        current_saved_dict['track'] = [i['track']['name'] for i in results['items']]
        current_saved_dict['artist'] = [i['track']['artists'][0]['name'] for i in results['items']]
        current_saved_dict['album'] = [i['track']['album']['name'] for i in results['items']]
        current_saved_dict['popularity_score'] = [i['track']['popularity'] for i in results['items']]
        current_saved_dict['track_id'] = [i['track']['id'] for i in results['items']]
        current_saved_dict['track_uri'] = [i['track']['uri'] for i in results['items']]
        current_saved_dict['spotify_link'] = [i['track']['external_urls']['spotify'] for i in results['items']]
        current_saved_dict['preview'] = [i['track']['preview_url'] for i in results['items']]
        current_saved_dict['album_image_large'] = [i['track']['album']['images'][1]['url'] for i in results['items']]
        current_saved_dict['album_image_small'] = [i['track']['album']['images'][2]['url'] for i in results['items']]
    
        if i == 0:
            df = pd.DataFrame(current_saved_dict)
        
        else:
            df = pd.concat([df, pd.DataFrame(current_saved_dict)])
            df.reset_index(drop = True, inplace = True)
    
    return df

# %% [markdown]
# ### User Recently Played

# %%
def get_recent_played(var = None):
    
    results = sp.current_user_recently_played()

    recent_played_dict = {}

    recent_played_dict['track'] = [i['track']['name'] for i in results['items']]
    recent_played_dict['artist'] = [i['track']['artists'][0]['name'] for i in results['items']]
    recent_played_dict['album'] = [i['track']['album']['name'] for i in results['items']]
    recent_played_dict['popularity_score'] = [i['track']['popularity'] for i in results['items']]
    recent_played_dict['track_id'] = [i['track']['id'] for i in results['items']]
    recent_played_dict['track_uri'] = [i['track']['uri'] for i in results['items']]
    recent_played_dict['spotify_link'] = [i['track']['external_urls']['spotify'] for i in results['items']]
    recent_played_dict['preview'] = [i['track']['preview_url'] for i in results['items']]
    recent_played_dict['album_image_large'] = [i['track']['album']['images'][1]['url'] for i in results['items']]
    recent_played_dict['album_image_small'] = [i['track']['album']['images'][2]['url'] for i in results['items']]
    
    return pd.DataFrame(recent_played_dict).drop_duplicates().reset_index(drop = True)

# %% [markdown]
# ### Get Tracks w/ Audio Features

# %%
def get_tracks_w_audio_features(var = None):
    
    all_tracks_df = pd.concat([get_top_tracks(), get_current_saved(), get_recent_played()], axis = 0)
    all_tracks_df.drop_duplicates(inplace = True)
    all_tracks_df.reset_index(drop = True, inplace = True)
    
    df = None
    start = 0
    end = 100
    
    for i in range((len(all_tracks_df['track_id']) // 100) + 1):
    
        if i == (len(all_tracks_df['track_id']) // 100):
            results = sp.audio_features(tracks = list(all_tracks_df['track_id'])[start:len(all_tracks_df['track_id'])])
        else: 
            results = sp.audio_features(tracks = list(all_tracks_df['track_id'])[start:end])

        audio_dict = {}
        keep_features = ['danceability', 'energy', 'key', 'loudness', 'mode',
                         'speechiness', 'acousticness', 'instrumentalness', 'liveness',
                         'valence', 'tempo', 'id', 'duration_ms', 'time_signature']

        for i in keep_features:
            audio_dict[i] = [x[i] for x in results]
        
        if i == 0:
            df = pd.DataFrame(audio_dict)
        else:
            df = pd.concat([df, pd.DataFrame(audio_dict)])
            df.reset_index(drop = True, inplace = True)
        
        start += 100
        end += 100
    
    return pd.merge(all_tracks_df, df.rename(columns = {'id':'track_id'}), on = 'track_id', how = 'inner')

# %%
user_tracks_df = get_tracks_w_audio_features()
user_tracks_df.head()
# Out:
#                       track          artist                      album  \
# 0           Climbing a Wall          Floral                  Floral EP
# 1                   ROXANNE  Arizona Zervas                    ROXANNE
# 2                   I'm God    Clams Casino        Instrumental Relics
# 3                 Thank You            Dido                   No Angel
# 4  BLIND (feat. Young Thug)          DaBaby  BLAME IT ON BABY (DELUXE)
#
#    popularity_score                track_id  \
# 0                39  2GZLWeDxVyCxDBdVzVjbMi
# 1                88  696DnlkuDOXcMAnKlTgXXK
# 2                63  0FVuyC9RP5MACjp4lgU3qZ
# 3                71  3yUcJwYu7fXAfqMj9krY6l
# 4                79  2T5NBwKRySiCR78vVk08vr
#
#                               track_uri  \
# 0  spotify:track:2GZLWeDxVyCxDBdVzVjbMi
# 1  spotify:track:696DnlkuDOXcMAnKlTgXXK
# 2  spotify:track:0FVuyC9RP5MACjp4lgU3qZ
# 3  spotify:track:3yUcJwYu7fXAfqMj9krY6l
# 4  spotify:track:2T5NBwKRySiCR78vVk08vr
#
#                                         spotify_link  \
# 0  https://open.spotify.com/track/2GZLWeDxVyCxDBd...
# 1  https://open.spotify.com/track/696DnlkuDOXcMAn...
# 2  https://open.spotify.com/track/0FVuyC9RP5MACjp...
# 3  https://open.spotify.com/track/3yUcJwYu7fXAfqM...
# 4  https://open.spotify.com/track/2T5NBwKRySiCR78...
#
#                                              preview  \
# 0  https://p.scdn.co/mp3-preview/e9074cec5dbf81b0...
# 1  https://p.scdn.co/mp3-preview/17c8499c72603f1a...
# 2  https://p.scdn.co/mp3-preview/b3b4e58ac20fe9b9...
# 3  https://p.scdn.co/mp3-preview/61c1b2d6f13f53af...
# 4  https://p.scdn.co/mp3-preview/0d8eb3d8a247f65d...
#
#                                    album_image_large  \
# 0  https://i.scdn.co/image/ab67616d00001e024ffed7...
# 1  https://i.scdn.co/image/ab67616d00001e02069a93...
# 2  https://i.scdn.co/image/ab67616d00001e029dd5e3...
# 3  https://i.scdn.co/image/ab67616d00001e023e5cbf...
# 4  https://i.scdn.co/image/ab67616d00001e02e818d0...
#
#                                    album_image_small  ...  loudness  mode  \
# 0  https://i.scdn.co/image/ab67616d000048514ffed7...  ...    -5.853     1
# 1  https://i.scdn.co/image/ab67616d00004851069a93...  ...    -5.616     0
# 2  https://i.scdn.co/image/ab67616d000048519dd5e3...  ...    -6.780     1
# 3  https://i.scdn.co/image/ab67616d000048513e5cbf...  ...    -9.942     0
# 4  https://i.scdn.co/image/ab67616d00004851e818d0...  ...    -6.503     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0436        0.0177          0.286000    0.0890    0.678  151.097
# 1       0.1480        0.0522          0.000000    0.4600    0.457  116.735
# 2       0.0336        0.0711          0.760000    0.1020    0.089  141.927
# 3       0.0424        0.3000          0.000215    0.0665    0.765   79.984
# 4       0.3460        0.0115          0.000000    0.0971    0.754  162.973
#
#    duration_ms  time_signature
# 0       219266               1
# 1       163636               5
# 2       277711               4
# 3       218360               4
# 4       153467               4
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Song Lyrics - Genius API

# %%
genius_cid = 'CcpHS1g5r7-WS44TjJ3sj6ArKwxRIOy8uBvBDMBR0nSqNqm5KrkR83hkoOkxBZpA'
genius_secret = 'ZnKfkN0tdVp8__7WTSkY4QnLtJaPz44lmG7iLjlnIXdLuZZrh0Bqud6FdERuq3uauroUBJGsnQqQCJOgnqwq7A'
token = '4rG9_aw6EWk-qxxhSwLhgoLi7KjjNJm-kERUuakfWtJQZLYr5pbLLE0mt8_5vBV7'

genius = lyricsgenius.Genius(token)

genius.remove_section_headers = True
genius.verbose = False

# %%
def get_lyrics(var = None):

    lyrics_lst = []

    for i in range(len(user_tracks_df.index)):
        song = genius.search_song(list(user_tracks_df['track'])[i], list(user_tracks_df['artist'])[i])

        try:
            if list(user_tracks_df['track'])[i] == song.title or list(user_tracks_df['artist'])[i] == song.artist:
                lyrics_lst.append(sub('\n', ' ', song.lyrics).lower())
            else:
                lyrics_lst.append(np.nan)
        except:
            lyrics_lst.append(np.nan)

        sleep(0.5)

    return lyrics_lst

# %%
# %%time
user_tracks_df['lyrics'] = get_lyrics()
# Out:
# CPU times: user 14.6 s, sys: 1.15 s, total: 15.8 s
# Wall time: 8min 48s

# %%
user_tracks_df.isnull().sum()
# Out:
# track                 0
# artist                0
# album                 0
# popularity_score      0
# track_id              0
# track_uri             0
# spotify_link          0
# preview              16
# album_image_large     0
# album_image_small     0
# danceability          0
# energy                0
# key                   0
# loudness              0
# mode                  0
# speechiness           0
# acousticness          0
# instrumentalness      0
# liveness              0
# valence               0
# tempo                 0
# duration_ms           0
# time_signature        0
# lyrics               80
# dtype: int64

# %%
user_tracks_df.head(10)
# Out:
#                                                track          artist  \
# 0                                    Climbing a Wall          Floral
# 1                                            ROXANNE  Arizona Zervas
# 2                                            I'm God    Clams Casino
# 3                                          Thank You            Dido
# 4                           BLIND (feat. Young Thug)          DaBaby
# 5                                              Opaul   Freddie Dredd
# 6                         Roses Remix (feat. Future)       SAINt JHN
# 7                                           Many Men       21 Savage
# 8  WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil W...     Jack Harlow
# 9                                        Do My Dance            Tyga
#
#                                                album  popularity_score  \
# 0                                          Floral EP                39
# 1                                            ROXANNE                88
# 2                                Instrumental Relics                63
# 3                                           No Angel                71
# 4                          BLAME IT ON BABY (DELUXE)                79
# 5                                         Pink Lotus                66
# 6                         Roses Remix (feat. Future)                71
# 7                                     SAVAGE MODE II                75
# 8  WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil W...                88
# 9                                        Do My Dance                56
#
#                  track_id                             track_uri  \
# 0  2GZLWeDxVyCxDBdVzVjbMi  spotify:track:2GZLWeDxVyCxDBdVzVjbMi
# 1  696DnlkuDOXcMAnKlTgXXK  spotify:track:696DnlkuDOXcMAnKlTgXXK
# 2  0FVuyC9RP5MACjp4lgU3qZ  spotify:track:0FVuyC9RP5MACjp4lgU3qZ
# 3  3yUcJwYu7fXAfqMj9krY6l  spotify:track:3yUcJwYu7fXAfqMj9krY6l
# 4  2T5NBwKRySiCR78vVk08vr  spotify:track:2T5NBwKRySiCR78vVk08vr
# 5  4areFtLMjGt4GmO4IAbGo0  spotify:track:4areFtLMjGt4GmO4IAbGo0
# 6  1KyZ4rUiW2lkqGNLQYKpcC  spotify:track:1KyZ4rUiW2lkqGNLQYKpcC
# 7  3CDVMejYHnB1SkEEx0T1N4  spotify:track:3CDVMejYHnB1SkEEx0T1N4
# 8  2MbdDtCv5LUVjYy9RuGTgC  spotify:track:2MbdDtCv5LUVjYy9RuGTgC
# 9  7Hk12JkCFwLO4s1jRGBS6s  spotify:track:7Hk12JkCFwLO4s1jRGBS6s
#
#                                         spotify_link  \
# 0  https://open.spotify.com/track/2GZLWeDxVyCxDBd...
# 1  https://open.spotify.com/track/696DnlkuDOXcMAn...
# 2  https://open.spotify.com/track/0FVuyC9RP5MACjp...
# 3  https://open.spotify.com/track/3yUcJwYu7fXAfqM...
# 4  https://open.spotify.com/track/2T5NBwKRySiCR78...
# 5  https://open.spotify.com/track/4areFtLMjGt4GmO...
# 6  https://open.spotify.com/track/1KyZ4rUiW2lkqGN...
# 7  https://open.spotify.com/track/3CDVMejYHnB1SkE...
# 8  https://open.spotify.com/track/2MbdDtCv5LUVjYy...
# 9  https://open.spotify.com/track/7Hk12JkCFwLO4s1...
#
#                                              preview  \
# 0  https://p.scdn.co/mp3-preview/e9074cec5dbf81b0...
# 1  https://p.scdn.co/mp3-preview/17c8499c72603f1a...
# 2  https://p.scdn.co/mp3-preview/b3b4e58ac20fe9b9...
# 3  https://p.scdn.co/mp3-preview/61c1b2d6f13f53af...
# 4  https://p.scdn.co/mp3-preview/0d8eb3d8a247f65d...
# 5  https://p.scdn.co/mp3-preview/3ef6e974469be45d...
# 6  https://p.scdn.co/mp3-preview/af9080fbaac455c0...
# 7  https://p.scdn.co/mp3-preview/850704c41a453d9a...
# 8  https://p.scdn.co/mp3-preview/3748f897bbea6068...
# 9  https://p.scdn.co/mp3-preview/05afc686308b60b7...
#
#                                    album_image_large  \
# 0  https://i.scdn.co/image/ab67616d00001e024ffed7...
# 1  https://i.scdn.co/image/ab67616d00001e02069a93...
# 2  https://i.scdn.co/image/ab67616d00001e029dd5e3...
# 3  https://i.scdn.co/image/ab67616d00001e023e5cbf...
# 4  https://i.scdn.co/image/ab67616d00001e02e818d0...
# 5  https://i.scdn.co/image/ab67616d00001e02d03785...
# 6  https://i.scdn.co/image/ab67616d00001e021dec94...
# 7  https://i.scdn.co/image/ab67616d00001e02aa5790...
# 8  https://i.scdn.co/image/ab67616d00001e02b5f0a8...
# 9  https://i.scdn.co/image/ab67616d00001e028dd3aa...
#
#                                    album_image_small  ...  mode  speechiness  \
# 0  https://i.scdn.co/image/ab67616d000048514ffed7...  ...     1       0.0436
# 1  https://i.scdn.co/image/ab67616d00004851069a93...  ...     0       0.1480
# 2  https://i.scdn.co/image/ab67616d000048519dd5e3...  ...     1       0.0336
# 3  https://i.scdn.co/image/ab67616d000048513e5cbf...  ...     0       0.0424
# 4  https://i.scdn.co/image/ab67616d00004851e818d0...  ...     0       0.3460
# 5  https://i.scdn.co/image/ab67616d00004851d03785...  ...     1       0.2130
# 6  https://i.scdn.co/image/ab67616d000048511dec94...  ...     1       0.1130
# 7  https://i.scdn.co/image/ab67616d00004851aa5790...  ...     0       0.0322
# 8  https://i.scdn.co/image/ab67616d00004851b5f0a8...  ...     0       0.2600
# 9  https://i.scdn.co/image/ab67616d000048518dd3aa...  ...     1       0.0805
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0      0.017700          0.286000    0.0890    0.678  151.097       219266
# 1      0.052200          0.000000    0.4600    0.457  116.735       163636
# 2      0.071100          0.760000    0.1020    0.089  141.927       277711
# 3      0.300000          0.000215    0.0665    0.765   79.984       218360
# 4      0.011500          0.000000    0.0971    0.754  162.973       153467
# 5      0.005550          0.498000    0.0983    0.638  145.031       140488
# 6      0.024700          0.000055    0.1920    0.312  127.003       187898
# 7      0.000647          0.747000    0.1130    0.281   77.594       201856
# 8      0.063100          0.000000    0.1850    0.835  145.013       227478
# 9      0.003570          0.001660    0.1320    0.746  153.950       214293
#
#    time_signature                                             lyrics
# 0               1                                                NaN
# 1               5  all for the 'gram bitches love the 'gram oh, w...
# 2               4                                                NaN
# 3               4  my tea's gone cold, i'm wondering why i got ou...
# 4               4  yeah, yeah, yeah i've been blind for a while n...
# 5               4  oh david, não vai não agora que esse som tá fi...
# 6               4  remix off the corner with the money, i got a b...
# 7               4  metro ayy, ayy, ayy, ayy, ayy, ayy  i kept it ...
# 8               4  back with the remix these boys all my sons lik...
# 9               4  fuck this pussy boy, fuck it! (fuck it right b...
#
# [10 rows x 24 columns]

# %% [markdown]
# ### Export Tracks Dataframe

# %%
user_tracks_df.to_csv('./datasets/aziz_tracks.csv', index = False)
