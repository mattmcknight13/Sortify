# %% [markdown]
# # Sortify - GA Capstone

# %% [markdown]
# ##### Aziz Maredia | DSIR-1019 | 01.27.21

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# I am going to build a music recommender system using the Spotify and Genius APIs. The app will sort an ablum entered in the order of songs the user will mostly likely like by analyzing the audio features and lyrics of the users recently saved tracks, recently played tracks, and top tracks.

# %% [markdown]
# ### Library/Packages Import

# %%
import pandas as pd
import numpy as np
from math import floor

import spotipy
from spotipy.oauth2 import SpotifyOAuth

from PIL import Image
from requests import get

from flask import Flask, render_template, redirect, request, session, make_response,session,redirect

pd.set_option('display.max_rows', None)

# %% [markdown]
# ### API User Authorization

# %%
cid = '01e5c3c39a334ae78bf5becf053ad2d5'
secret = '3c481468946e43dc9da43ed6b5c16bc8'
uri = 'http://localhost:9999/lab/workspaces/auto-c'
cache = '.spotipyoauthcache'
scope = 'user-library-read user-library-modify'

# %%
auth = SpotifyOAuth(client_id = cid,
                    client_secret = secret,
                    redirect_uri = uri,
                    cache_path = cache,
                    scope = scope)

sp = spotipy.Spotify(oauth_manager = auth)

# %%
user = sp.current_user()
user_name = user['display_name']
user_profile = user['external_urls']['spotify']

# %%
name = user['display_name'].split()[0]

# %%
print(f'Hello {user_name.split()[0]}! Click the following link to view your Spoitfy profile: {user_profile}')
# Out:
# Hello Aziz! Click the following link to view your Spoitfy profile: https://open.spotify.com/user/1282060363

# %% [markdown]
# ### Collect All User Saved Tracks

# %%
def get_current_saved(var = None):
    
    # set empty variable for dataframe to be assigned to
    df = None
    
    # set variable to check number of rows in dataframe
    num_rows = 0
    
    # api can pull max of 20 tracks at a time and a spotify user can have a max of 10,000 songs saved
    for i in range(0, 10000, 20):
        
        # call api endpoint to collect saved tracks. offset equals index of first song being pull and increases by 20 each interation
        results = sp.current_user_saved_tracks(offset = i)
        
        # set empty dict for track variables and values collected to be stored in
        current_saved_dict = {}
        current_saved_dict['track'] = [i['track']['name'] for i in results['items']]
        current_saved_dict['artist'] = [i['track']['artists'][0]['name'] for i in results['items']]
        current_saved_dict['track_id'] = [i['track']['id'] for i in results['items']]
        current_saved_dict['artist_id'] = [i['track']['artists'][0]['id'] for i in results['items']]
        current_saved_dict['release_date'] = [i['track']['album']['release_date'] for i in results['items']]
        current_saved_dict['popularity_song'] = [i['track']['popularity'] for i in results['items']]
    
        # if first iteration, convert dict to dataframe and save to empty df variable
        # if not, convert dict to dataframe and concat it with dataframe contatining tracks from previous pulls
        if i == 0:
            df = pd.DataFrame(current_saved_dict)
        else:
            df = pd.concat([df, pd.DataFrame(current_saved_dict)])
            df.reset_index(drop = True, inplace = True)
        
        # if length of dataframe index equals the num_rows variable set above, this means that we have pulled all songs in a user's library
        # if not, update num_rows to current index length
        if len(df.index) == num_rows:
            return df
        else:
            num_rows = len(df.index)
    
    return df

# %% [markdown]
# ### Collect Audio Features of Tracks

# %%
def get_audio_features(all_tracks_df):
        
    df = None
    start = 0
    end = 100
    
    # api can only pull audio features for 100 tracks max
    # calculting how many pulls will be need based on number of tracks in user's saved library
    for i in range((len(all_tracks_df['track_id']) // 100) + 1):
        
        # XXX
        if i == (len(all_tracks_df['track_id']) // 100):
            results = sp.audio_features(tracks = list(all_tracks_df['track_id'])[start:len(all_tracks_df['track_id'])])
        else: 
            results = sp.audio_features(tracks = list(all_tracks_df['track_id'])[start:end])
        
        # XXX
        audio_dict = {}
        keep_features = ['danceability', 'energy', 'key', 'loudness', 'mode',
                         'speechiness', 'acousticness', 'instrumentalness', 'liveness',
                         'valence', 'tempo', 'id', 'duration_ms', 'time_signature']

        for i in keep_features:
            audio_dict[i] = [x[i] for x in results]
        
        # if first iteration, convert dict to dataframe and save to empty df variable
        # if not, convert dict to dataframe and concat it with dataframe contatining tracks from previous pulls
        if i == 0:
            df = pd.DataFrame(audio_dict)
        else:
            df = pd.concat([df, pd.DataFrame(audio_dict)])
            df.reset_index(drop = True, inplace = True)
        
        start += 100
        end += 100
    
    return df

# %% [markdown]
# ### Collect Track Artist Information

# %%
def get_genres(all_tracks_df):
        
    df = None
    start = 0
    end = 50
    
    artists = list((set(list(all_tracks_df['artist_id']))))
    
    
    for i in range((len(artists) // 50) + 1):
    
        if i == (len(artists) // 50):
            results = sp.artists(artists = artists[start:len(artists)])
        else: 
            results = sp.artists(artists = artists[start:end])

        audio_dict = {}
        keep_features = ['id', 'popularity', 'genres']

        for i in keep_features:
            audio_dict[i] = [x[i] for x in results['artists']]
        
        if i == 0:
            df = pd.DataFrame(audio_dict)
        else:
            df = pd.concat([df, pd.DataFrame(audio_dict)])
            df.reset_index(drop = True, inplace = True)
        
        start += 50
        end += 50
    
    df.rename(columns = {'popularity': 'popularity_artist'}, inplace = True)
    
    return df

# %% [markdown]
# ### Collect All Tracks & Information Calling Functions Above

# %%
def get_user_tracks_w_audio_features(var = None):
    
    all_tracks_df = get_current_saved()
    
    audio_features_df = get_audio_features(all_tracks_df)
    
    df = pd.merge(all_tracks_df, audio_features_df.rename(columns = {'id':'track_id'}), on = 'track_id', how = 'inner')
    
    genres_df = get_genres(all_tracks_df)
    
    df = pd.merge(df, genres_df.rename(columns = {'id':'artist_id'}), on = 'artist_id', how = 'left')
    
    df['data_type'] = 'user_library'
    
    df = df[['track', 'artist', 'data_type', 'popularity_artist', 'popularity_song', 
             'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 
             'liveness', 'valence', 'tempo', 'mode', 'key', 'time_signature', 'release_date', 'genres']]
    
    return df

# %%
# %%time
user_tracks_df = get_user_tracks_w_audio_features()
# Out:
# CPU times: user 912 ms, sys: 83.3 ms, total: 995 ms
# Wall time: 17.2 s

# %%
user_tracks_df.shape
# Out:
# (1524, 19)

# %%
user_tracks_df.head()
# Out:
#                          track          artist     data_type  \
# 0  JustYourSoul - Tchami Remix  Valentino Khan  user_library
# 1                   Moving Men             Myd  user_library
# 2             Sonate Pacifique   L'Impératrice  user_library
# 3                        Casio          Jungle  user_library
# 4     Music Is My Hot, Hot Sex             CSS  user_library
#
#    popularity_artist  popularity_song  danceability  energy  loudness  \
# 0                 64             48.0         0.749   0.846    -3.441
# 1                 57             60.0         0.815   0.661    -8.208
# 2                 63             63.0         0.558   0.538    -8.853
# 3                 66             67.0         0.816   0.492    -7.464
# 4                 46              0.0         0.742   0.723    -5.620
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0932       0.00403           0.00525    0.0382    0.532  124.935
# 1       0.0996       0.10600           0.26600    0.2840    0.699  124.991
# 2       0.0327       0.62900           0.01980    0.4240    0.254   99.992
# 3       0.0752       0.43100           0.08960    0.0995    0.765  115.989
# 4       0.0441       0.01370           0.00127    0.0610    0.927  100.016
#
#    mode  key  time_signature release_date  \
# 0     1    2               4   2020-01-10
# 1     1   10               3   2020-10-28
# 2     1    5               4   2014-09-22
# 3     0   10               4   2018-09-14
# 4     0    8               4   2007-01-22
#
#                                               genres
# 0  [bass house, brostep, edm, electro house, elec...
# 1  [filter house, french indie pop, french indiet...
# 2  [french indie pop, french indietronica, french...
# 3                  [indie soul, uk contemporary r&b]
# 4  [alternative dance, dance-punk, electroclash, ...

# %% [markdown]
# ### Collect Album User Would Like to Sort

# %%
def get_album_tracks(album_to_search):

    results = sp.search(album_to_search, 1, 0, 'album', None)
    album_id = results['albums']['items'][0]['id']

    df = None
    
    results2 = sp.album(album_id)

    album_tracks_dict = {}

    album_tracks_dict['track'] = [i['name'] for i in results2['tracks']['items']]
    album_tracks_dict['track_id'] = [i['id'] for i in results2['tracks']['items']]
    album_tracks_dict['artist'] = [i['artists'][0]['name'] for i in results2['tracks']['items']]
    album_tracks_dict['artist_id'] = [i['artists'][0]['id'] for i in results2['tracks']['items']]
    album_tracks_dict['spotify_link'] = [i['external_urls']['spotify'] for i in results2['tracks']['items']]
    album_tracks_dict['preview'] = [i['preview_url'] for i in results2['tracks']['items']]
    
    df = pd.DataFrame(album_tracks_dict)
    album_dict = {}
    
    album_dict['album_name'] = results2['name'] # album title
    album_dict['artist_name'] = results2['artists'][0]['name'] # artist name
    album_dict['release_year'] = results2['release_date'][:4] # release_year
    album_dict['total_tracks'] = results2['total_tracks'] # total tracks
    album_dict['album_link'] = results2['external_urls']['spotify']
    album_dict['artist_link'] = results2['artists'][0]['external_urls']['spotify']
    
    album_image = Image.open(get(results2['images'][1]['url'], stream = True).raw)
    album_dict['album_image'] = album_image.resize((300, 300))
    
    minutes = sum([i['duration_ms'] for i in results2['tracks']['items']]) / 60000
    
    if minutes > 60:
        album_dict['album_duration'] = f'{int(minutes // 60)} hr {floor(minutes % 60)} min'
    else:
        album_dict['album_duration'] = f'{floor(minutes)} min {floor((minutes - floor(minutes)) * 60)} sec'
    
#     df['album'] = album_dict['album_name']
#     df['album_image_large'] = album_dict['album_image']
    df['release_date'] = results2['release_date']
    

    results3 = sp.tracks(tracks = list(df['track_id']))
    
    df['popularity_song'] = [[i][0]['popularity'] for i in results3['tracks']]

    df_audio = get_audio_features(df)
    df = pd.merge(df, df_audio.rename(columns = {'id':'track_id'}), on = 'track_id', how = 'inner')
    
    df_genres = get_genres(df)
    df = pd.merge(df, df_genres.rename(columns = {'id':'artist_id'}), on = 'artist_id', how = 'left')
    
    df['data_type'] = 'album'
    
    df = df[['track', 'artist', 'track_id', 'spotify_link', 'preview', 'data_type', 'duration_ms', 'popularity_artist', 
             'popularity_song', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 
             'instrumentalness', 'liveness', 'valence', 'tempo', 'mode', 'key', 'time_signature', 'release_date', 'genres']]
                                 
    return df, album_dict

# %%
# %%time
album_tracks_df, album_info_dict = get_album_tracks('Man on the Moon III: The Chosen')
# Out:
# CPU times: user 80.1 ms, sys: 14.9 ms, total: 95 ms
# Wall time: 736 ms

# %%
album_info_dict
# Out:
# {'album_name': 'Man On The Moon III: The Chosen',
#  'artist_name': 'Kid Cudi',
#  'release_year': '2020',
#  'total_tracks': 18,
#  'album_link': 'https://open.spotify.com/album/64nbgEEIcY4g1ElVLONJ0w',
#  'artist_link': 'https://open.spotify.com/artist/0fA0VVWsXO9YnASrzqfmYu',
#  'album_image': <PIL.Image.Image image mode=RGB size=300x300 at 0x7FC48EC76550>,
#  'album_duration': '58 min 24 sec'}

# %%
album_tracks_df.shape
# Out:
# (18, 23)

# %%
album_tracks_df.head(50)
# Out:
#                                    track    artist                track_id  \
# 0                         Beautiful Trip  Kid Cudi  4IIuCotvqijraSdnVLaFnM
# 1                          Tequila Shots  Kid Cudi  30KctD1WsHKTIYczXjip5a
# 2                            Another Day  Kid Cudi  6myUpr3GDR80Dg3zqNTmmG
# 3                         She Knows This  Kid Cudi  1xzUQMiCoY5pdego0pHMeV
# 4                                   Dive  Kid Cudi  7Hc3YL8oDiAzbiAW32KXrw
# 5                                Damaged  Kid Cudi  2n7Ao4nyESBa5ti8gcAbBt
# 6                        Heaven On Earth  Kid Cudi  2koUj1Fn5TKFEkChSmBPIb
# 7     Show Out (with Skepta & Pop Smoke)  Kid Cudi  5CFJRZRq6sdKKtRwNPWbYv
# 8                     Solo Dolo, Pt. III  Kid Cudi  27oVCAziETRbNuo5A8LNpg
# 9                             Sad People  Kid Cudi  4nuAslShoN77tq12fzwjUq
# 10          Elsie's Baby Boy (flashback)  Kid Cudi  6jiwr6xTHqjdun5d3cEwXV
# 11                              Sept. 16  Kid Cudi  3Uw2se3aQU1UFrpRBvBnB4
# 12                              The Void  Kid Cudi  2yg7MXp8nSPaf61HVkhEr3
# 13     Lovin’ Me (feat. Phoebe Bridgers)  Kid Cudi  3JdwGk8j7lHN5qdzJZklam
# 14                    The Pale Moonlight  Kid Cudi  4EjbAh7YHU3VARkfkamZ8R
# 15  Rockstar Knights (with Trippie Redd)  Kid Cudi  4J9SI7do4KOEsCexqEbjmR
# 16                             4 Da Kidz  Kid Cudi  2ZDRkJrKbceJRgLKkuex14
# 17                           Lord I Know  Kid Cudi  7f2voPcnDEAzX4yB8SLnU2
#
#                                          spotify_link  \
# 0   https://open.spotify.com/track/4IIuCotvqijraSd...
# 1   https://open.spotify.com/track/30KctD1WsHKTIYc...
# 2   https://open.spotify.com/track/6myUpr3GDR80Dg3...
# 3   https://open.spotify.com/track/1xzUQMiCoY5pdeg...
# 4   https://open.spotify.com/track/7Hc3YL8oDiAzbiA...
# 5   https://open.spotify.com/track/2n7Ao4nyESBa5ti...
# 6   https://open.spotify.com/track/2koUj1Fn5TKFEkC...
# 7   https://open.spotify.com/track/5CFJRZRq6sdKKtR...
# 8   https://open.spotify.com/track/27oVCAziETRbNuo...
# 9   https://open.spotify.com/track/4nuAslShoN77tq1...
# 10  https://open.spotify.com/track/6jiwr6xTHqjdun5...
# 11  https://open.spotify.com/track/3Uw2se3aQU1UFrp...
# 12  https://open.spotify.com/track/2yg7MXp8nSPaf61...
# 13  https://open.spotify.com/track/3JdwGk8j7lHN5qd...
# 14  https://open.spotify.com/track/4EjbAh7YHU3VARk...
# 15  https://open.spotify.com/track/4J9SI7do4KOEsCe...
# 16  https://open.spotify.com/track/2ZDRkJrKbceJRgL...
# 17  https://open.spotify.com/track/7f2voPcnDEAzX4y...
#
#                                               preview data_type  duration_ms  \
# 0   https://p.scdn.co/mp3-preview/05edcc06fc085a58...     album        37013
# 1   https://p.scdn.co/mp3-preview/eea2485b714dffab...     album       193293
# 2   https://p.scdn.co/mp3-preview/0270d8150fcbd742...     album       199787
# 3   https://p.scdn.co/mp3-preview/29dc43127abc4fde...     album       216560
# 4   https://p.scdn.co/mp3-preview/89e0c1d79d7d17f4...     album       148707
# 5   https://p.scdn.co/mp3-preview/393f2cf8af310e83...     album       150853
# 6   https://p.scdn.co/mp3-preview/2835c7cd7c80c80c...     album       201093
# 7   https://p.scdn.co/mp3-preview/7b310f6822a15aea...     album       174960
# 8   https://p.scdn.co/mp3-preview/c461629a7f1acf31...     album       242267
# 9   https://p.scdn.co/mp3-preview/a2e8a2ffade8b892...     album       176027
# 10  https://p.scdn.co/mp3-preview/62530a94d72e2613...     album       219213
# 11  https://p.scdn.co/mp3-preview/62578afedb81632e...     album       249040
# 12  https://p.scdn.co/mp3-preview/698c2b64f5d5d4b0...     album       325413
# 13  https://p.scdn.co/mp3-preview/fe1dcbc39d22cd33...     album       165893
# 14  https://p.scdn.co/mp3-preview/e7c6614a297ba664...     album       176293
# 15  https://p.scdn.co/mp3-preview/d0610339176bd8c2...     album       231467
# 16  https://p.scdn.co/mp3-preview/63c613329bc5c48a...     album       184240
# 17  https://p.scdn.co/mp3-preview/db8ec4c01236346a...     album       212040
#
#     popularity_artist  popularity_song  danceability  ...  acousticness  \
# 0                  90               70         0.331  ...         0.972
# 1                  90               84         0.712  ...         0.084
# 2                  90               77         0.646  ...         0.556
# 3                  90               79         0.390  ...         0.162
# 4                  90               75         0.640  ...         0.670
# 5                  90               73         0.625  ...         0.553
# 6                  90               74         0.786  ...         0.379
# 7                  90               84         0.619  ...         0.430
# 8                  90               75         0.589  ...         0.239
# 9                  90               75         0.636  ...         0.247
# 10                 90               71         0.534  ...         0.230
# 11                 90               72         0.646  ...         0.764
# 12                 90               74         0.464  ...         0.365
# 13                 90               73         0.604  ...         0.152
# 14                 90               72         0.576  ...         0.455
# 15                 90               74         0.625  ...         0.384
# 16                 90               71         0.410  ...         0.407
# 17                 90               72         0.613  ...         0.583
#
#     instrumentalness  liveness  valence    tempo  mode  key  time_signature  \
# 0           0.953000    0.8820   0.4200  133.971     0   11               4
# 1           0.000050    0.5270   0.2200   90.494     0    5               4
# 2           0.003160    0.3350   0.0642  172.995     0    4               4
# 3           0.000000    0.3930   0.3120  165.945     0    6               4
# 4           0.000000    0.3600   0.3320  123.105     0    9               4
# 5           0.001110    0.2540   0.2670  142.040     1    8               4
# 6           0.000820    0.0765   0.2280  130.036     1    0               4
# 7           0.000392    0.3780   0.1580  143.896     1    1               4
# 8           0.027700    0.1640   0.5200  152.058     0   10               4
# 9           0.001230    0.1130   0.4160  158.073     0    5               4
# 10          0.452000    0.3660   0.1340   95.158     0    2               3
# 11          0.114000    0.1370   0.4730  140.987     0    4               4
# 12          0.280000    0.1170   0.0786  142.017     0    7               4
# 13          0.000845    0.1570   0.1680  141.527     1    1               4
# 14          0.000066    0.2090   0.6120  160.009     0    7               4
# 15          0.000005    0.3370   0.3840  178.052     0    6               4
# 16          0.142000    0.6350   0.3930  134.224     1    5               5
# 17          0.295000    0.1020   0.0389  180.061     1    0               4
#
#     release_date                        genres
# 0     2020-12-11  [hip hop, ohio hip hop, rap]
# 1     2020-12-11  [hip hop, ohio hip hop, rap]
# 2     2020-12-11  [hip hop, ohio hip hop, rap]
# 3     2020-12-11  [hip hop, ohio hip hop, rap]
# 4     2020-12-11  [hip hop, ohio hip hop, rap]
# 5     2020-12-11  [hip hop, ohio hip hop, rap]
# 6     2020-12-11  [hip hop, ohio hip hop, rap]
# 7     2020-12-11  [hip hop, ohio hip hop, rap]
# 8     2020-12-11  [hip hop, ohio hip hop, rap]
# 9     2020-12-11  [hip hop, ohio hip hop, rap]
# 10    2020-12-11  [hip hop, ohio hip hop, rap]
# 11    2020-12-11  [hip hop, ohio hip hop, rap]
# 12    2020-12-11  [hip hop, ohio hip hop, rap]
# 13    2020-12-11  [hip hop, ohio hip hop, rap]
# 14    2020-12-11  [hip hop, ohio hip hop, rap]
# 15    2020-12-11  [hip hop, ohio hip hop, rap]
# 16    2020-12-11  [hip hop, ohio hip hop, rap]
# 17    2020-12-11  [hip hop, ohio hip hop, rap]
#
# [18 rows x 23 columns]

# %%
album_final_model_df = album_tracks_df[['track', 'duration_ms', 'track_id', 'spotify_link', 'preview']]

# %%
album_final_model_df.to_csv('.././datasets/album_to_sort.csv', index = False)

# %%
album_final_model_df
# Out:
#                                    track  duration_ms                track_id  \
# 0                         Beautiful Trip        37013  4IIuCotvqijraSdnVLaFnM
# 1                          Tequila Shots       193293  30KctD1WsHKTIYczXjip5a
# 2                            Another Day       199787  6myUpr3GDR80Dg3zqNTmmG
# 3                         She Knows This       216560  1xzUQMiCoY5pdego0pHMeV
# 4                                   Dive       148707  7Hc3YL8oDiAzbiAW32KXrw
# 5                                Damaged       150853  2n7Ao4nyESBa5ti8gcAbBt
# 6                        Heaven On Earth       201093  2koUj1Fn5TKFEkChSmBPIb
# 7     Show Out (with Skepta & Pop Smoke)       174960  5CFJRZRq6sdKKtRwNPWbYv
# 8                     Solo Dolo, Pt. III       242267  27oVCAziETRbNuo5A8LNpg
# 9                             Sad People       176027  4nuAslShoN77tq12fzwjUq
# 10          Elsie's Baby Boy (flashback)       219213  6jiwr6xTHqjdun5d3cEwXV
# 11                              Sept. 16       249040  3Uw2se3aQU1UFrpRBvBnB4
# 12                              The Void       325413  2yg7MXp8nSPaf61HVkhEr3
# 13     Lovin’ Me (feat. Phoebe Bridgers)       165893  3JdwGk8j7lHN5qdzJZklam
# 14                    The Pale Moonlight       176293  4EjbAh7YHU3VARkfkamZ8R
# 15  Rockstar Knights (with Trippie Redd)       231467  4J9SI7do4KOEsCexqEbjmR
# 16                             4 Da Kidz       184240  2ZDRkJrKbceJRgLKkuex14
# 17                           Lord I Know       212040  7f2voPcnDEAzX4yB8SLnU2
#
#                                          spotify_link  \
# 0   https://open.spotify.com/track/4IIuCotvqijraSd...
# 1   https://open.spotify.com/track/30KctD1WsHKTIYc...
# 2   https://open.spotify.com/track/6myUpr3GDR80Dg3...
# 3   https://open.spotify.com/track/1xzUQMiCoY5pdeg...
# 4   https://open.spotify.com/track/7Hc3YL8oDiAzbiA...
# 5   https://open.spotify.com/track/2n7Ao4nyESBa5ti...
# 6   https://open.spotify.com/track/2koUj1Fn5TKFEkC...
# 7   https://open.spotify.com/track/5CFJRZRq6sdKKtR...
# 8   https://open.spotify.com/track/27oVCAziETRbNuo...
# 9   https://open.spotify.com/track/4nuAslShoN77tq1...
# 10  https://open.spotify.com/track/6jiwr6xTHqjdun5...
# 11  https://open.spotify.com/track/3Uw2se3aQU1UFrp...
# 12  https://open.spotify.com/track/2yg7MXp8nSPaf61...
# 13  https://open.spotify.com/track/3JdwGk8j7lHN5qd...
# 14  https://open.spotify.com/track/4EjbAh7YHU3VARk...
# 15  https://open.spotify.com/track/4J9SI7do4KOEsCe...
# 16  https://open.spotify.com/track/2ZDRkJrKbceJRgL...
# 17  https://open.spotify.com/track/7f2voPcnDEAzX4y...
#
#                                               preview
# 0   https://p.scdn.co/mp3-preview/05edcc06fc085a58...
# 1   https://p.scdn.co/mp3-preview/eea2485b714dffab...
# 2   https://p.scdn.co/mp3-preview/0270d8150fcbd742...
# 3   https://p.scdn.co/mp3-preview/29dc43127abc4fde...
# 4   https://p.scdn.co/mp3-preview/89e0c1d79d7d17f4...
# 5   https://p.scdn.co/mp3-preview/393f2cf8af310e83...
# 6   https://p.scdn.co/mp3-preview/2835c7cd7c80c80c...
# 7   https://p.scdn.co/mp3-preview/7b310f6822a15aea...
# 8   https://p.scdn.co/mp3-preview/c461629a7f1acf31...
# 9   https://p.scdn.co/mp3-preview/a2e8a2ffade8b892...
# 10  https://p.scdn.co/mp3-preview/62530a94d72e2613...
# 11  https://p.scdn.co/mp3-preview/62578afedb81632e...
# 12  https://p.scdn.co/mp3-preview/698c2b64f5d5d4b0...
# 13  https://p.scdn.co/mp3-preview/fe1dcbc39d22cd33...
# 14  https://p.scdn.co/mp3-preview/e7c6614a297ba664...
# 15  https://p.scdn.co/mp3-preview/d0610339176bd8c2...
# 16  https://p.scdn.co/mp3-preview/63c613329bc5c48a...
# 17  https://p.scdn.co/mp3-preview/db8ec4c01236346a...

# %% [markdown]
# ### Clean Genres Column

# %%
def clean_genres(df):
    
    genres = ['folk', 'gothic', 'emo', 'metal', 'rock', 'punk', 'alternative', 'grunge', 'pop', 'hip hop',
              'country', 'bluegrass', 'swing', 'blues', 'jazz', 'gospel', 'soul', 'piano', 'rythm', 'reggae',
              'rap', 'r&b', 'edm', 'dupstep', 'techno', 'house', 'trance', 'electro', 'dance', 'disco',
              'classical', 'singer songwriter', 'musical', 'african', 'hawaiian', 'jam band', 'psychedelic']
    
    languages = {'asian' : ['chinese', 'japanese', 'korean', 'korean pop', 'taiwanese', 'vietnamese', 'malaysian', 'indonesian', 'thai', 'tibetan'],
                 'baltic_slavic' : ['croatian', 'czech', 'latvian', 'polish', 'serbian', 'russian', 'lithuanian', 'ukrainian', 'slovenian', 'bulgarian'],
                 'celtic' : ['irish', 'scottish', 'celtic'],
                 'english' : ['australian', 'uk', 'british', 'canadian'],
                 'germanic' : ['german', 'norwegian', 'swedish', 'dutch', 'icelandic', 'austrian', 'danish', 'belgian'],
                 'indian_pakistani' : ['indian', 'pakistani', 'punjabi', 'hindustani'],
                 'middle_eastern' : ['israeli', 'kurdish', 'hebrew', 'arab', 'turkish'],
                 'romance' : ['spanish','french', 'italian', 'romanian', 'latin', 'portuguese'],
                 'south_american' : ['brazilian', 'venezuelan', 'argentine', 'peruvian', 'chilean'],
                 'uralic' : ['finnish', 'estonian', 'hungarian']}
    
    genres_list = []

    for i in df['genres']:

        temp = []

        for g in genres:
            if g in ' '.join(i):
                temp.append(g)

        for group in languages.keys():
            for l in languages[group]:
                if l in ' '.join(i):
                    temp.append(group)

        if len(temp) == 0:
            temp.append('other')

        genres_list.append(temp)
    
    df['genres'] = genres_list
    
    df = pd.concat([df, pd.get_dummies(df['genres'].apply(pd.Series).stack()).sum(level = 0)], axis = 1).drop(columns = ['genres'])
    
    return df

# %%
user_tracks_df.columns
# Out:
# Index(['track', 'artist', 'data_type', 'popularity_artist', 'popularity_song',
#        'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'mode', 'key',
#        'time_signature', 'release_date', 'genres'],
#       dtype='object')

# %%
album_concat = album_tracks_df[['track', 'artist', 'data_type', 'popularity_artist', 'popularity_song', 
                 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness',
                'liveness', 'valence', 'tempo', 'mode', 'key', 'time_signature', 'release_date', 'genres']]

# %%
combined_tracks_df = pd.concat([user_tracks_df, album_concat], axis = 0)
combined_tracks_df.reset_index(drop = True, inplace = True)

# %%
combined_tracks_df = clean_genres(combined_tracks_df)

# %%
combined_tracks_df.shape
# Out:
# (1542, 50)

# %%
combined_tracks_df.to_csv('.././datasets/combined_tracks.csv', index = False)
