# %%
import numpy as np

# %%
def ad(n, long_num):
    
    long_num = str(long_num)
    
    product = 0
    digit_list = None
    
    for digit in enumerate(long_num[:len(long_num) - n]):
        
        chunk_list = []
        chunk = long_num[digit[0]:digit[0] + n]
        
        for i in chunk:
            chunk_list.append(int(i))
        
        if np.prod(chunk_list) > product:
            product = np.prod(chunk_list)
            digit_list = chunk_list
    
    return num_list, product

# %%
long_num = ...

# %%
num_list, product = ad(13, long_num)

# %%
num_list
# Out:
# [5, 5, 7, 6, 6, 8, 9, 6, 6, 4, 8, 9, 5]

# %%
product
# Out:
# 23514624000
